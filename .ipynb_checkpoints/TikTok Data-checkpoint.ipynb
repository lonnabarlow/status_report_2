# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('final_data.csv', low_memory=False)

# %%
df.head()
# Out:
#             comment_id                                               text  \
# 0  6816879848683438085  But are you giving him a Tesla? Because he des...
# 1  6816846992812015622              David was just hoping for some help 😢
# 2  6816942564911628294  We ain’t forgot that time he tricked us all in...
# 3  6816824764519301125                                    get him a tesla
# 4  6816821633249001477                                   david ur so hung
#
#               video_id  create_time  like_count  status  author.unique_id  \
# 0  6816821384652557574   1587178528         161       1      lissettecalv
# 1  6816821384652557574   1587170875        1165       1  hellomyfriend0_o
# 2  6816821384652557574   1587193131         249       1     briancarrion_
# 3  6816821384652557574   1587165700        4038       1      slumpgodkayy
# 4  6816821384652557574   1587164971         100       1             _4den
#
#                author.nickname  author.is_private author.language  \
# ...

# %%
df.describe()
# Out:
#          comment_id      video_id   create_time     like_count    status  \
# count  1.651100e+05  1.651100e+05  1.651100e+05  165110.000000  165110.0
# mean   6.861607e+18  6.855808e+18  1.597592e+09      74.972588       1.0
# std    1.921583e+16  2.473814e+16  4.474037e+06    3593.935284       0.0
# min    6.816822e+18  6.816821e+18  1.587165e+09       0.000000       1.0
# 25%    6.846698e+18  6.831297e+18  1.594121e+09       0.000000       1.0
# 50%    6.872473e+18  6.872470e+18  1.600122e+09       3.000000       1.0
# 75%    6.872830e+18  6.872470e+18  1.600206e+09      19.000000       1.0
# max    6.879568e+18  6.877998e+18  1.601774e+09  773983.000000       1.0
#
#          author.uid  author.twitter_id
# count  1.651100e+05       9.800000e+01
# mean   5.926101e+18       8.467458e+17
# std    2.194139e+18       1.388873e+17
# min    8.963800e+04       4.388018e+08
# 25%    6.639025e+18       7.934457e+17
# 50%    6.755114e+18       7.934457e+17
# ...

# %%
df.shape
# Out:
# (165110, 20)

# %%
df.columns
# Out:
# Index(['comment_id', 'text', 'video_id', 'create_time', 'like_count', 'status',
#        'author.unique_id', 'author.nickname', 'author.is_private',
#        'author.language', 'author.signature', 'author.custom_verify',
#        'author.uid', 'author.sec_uid', 'author.avatar_thumb', 'author.region',
#        'author.ins_id', 'author.youtube_channel_title',
#        'author.youtube_channel_id', 'author.twitter_id'],
#       dtype='object')

# %%
df['like_count'].cumsum()
# Out:
# 0              161
# 1             1326
# 2             1575
# 3             5613
# 4             5713
#             ...
# 165105    12378694
# 165106    12378702
# 165107    12378710
# 165108    12378717
# 165109    12378724
# Name: like_count, Length: 165110, dtype: int64

# %% [markdown]
# Looking at the data, are there all unique users, or duplicates?

# %% [markdown]
# What is the amount of unique_id users that have their own you.tube channels?

# %% [markdown]
# What percent of users are active in all the coulumn requirements?
